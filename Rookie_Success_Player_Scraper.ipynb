# %% [markdown]
# <a href="https://colab.research.google.com/github/frankwillard/NBA-Rookie-Success-ML-Model/blob/main/Rookie_Success_Player_Scraper.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# May be in our interest to make a more generalizable set of functions in a script that we then import in each scraping notebook

# %%
import string
from urllib.request import urlopen, Request
from bs4 import BeautifulSoup
import pandas as pd
import re
import numpy as np
import bs4
import re
from datetime import date

# %%
def multiple_replace(dict, text):
  """
  Applies multiple replaces in string based on dictionary
  Args:
      dict ([type]): Dictionary with keys as phrase to be replaced, vals as phrase to replace key
      text ([type]): Text to apply string replaces to
  Returns:
      [type]: [description]
  """
  # Create a regular expression  from the dictionary keys
  regex = re.compile("(%s)" % "|".join(map(re.escape, dict.keys())))

  # For each match, look-up corresponding value in dictionary
  return regex.sub(lambda mo: dict[mo.string[mo.start():mo.end()]], text)

# %%
def dict_to_list(data_dict, cols_list, default_value):
  """

  Args:
    data_dict: Dictionary holding statistics/accolades corresponding to cols_list
    cols_list: List of columns in order for output DF
    default_value: Default value to fill if statistic/accolade not found


  Returns:
    List of accolade/statistics in order of columns in output DF

  """

  return [data_dict.get(col, default_value) for col in cols_list]

# %%
def get_physical_dictionary(soup):

  soup_text = soup.get_text()

  #Find Position in text and get substring based on bullets, strip other symbols
  #If multiple positions, grab first
  start_index = soup_text.find('Position:')
  end_index = soup_text.find(r'School:', start_index)

  physical_data = re.sub(r"[\n\t\s]*", "", soup_text[start_index:end_index])
  
  #Finds number- indicates height
  end_position = re.search(r"\d", physical_data).start()
  positions = physical_data[:end_position].split(':')[1]
  position = re.split(r',|and',positions)[0]
  
  end_height = physical_data.find(',')
  height_string = physical_data[end_position:end_height]
  ft, inches = height_string.split('-')
  height = int(ft) * 12 + int(inches)

  #Assumes a comma and a 3 digit weight
  weight = int(physical_data[end_height+1:end_height+4])

  physical_dict = {'Position': position}
  physical_dict['Height'] = height
  physical_dict['Weight'] = weight

  return physical_dict

# %%
def get_table_dictionary(soup, table_id, peak_stats = []):
  """

  Extracts player statistics from a table and returns in the form of a
  dictionary

  Args:
    soup: Soup extracted from an individual player's website on Basketball
     Reference
    table_id: ID tag for table in HTML denoting the type of statistics table to
     extract from (e.g. per_game, advanced, totals)

  
  Returns:
    [dict]: Returns a dictionary with the name of the statistic as the key
      and its corresponding value (based on the table- can be per game or
      totaled)

  """

  table = soup.find(id=f"players_{table_id}")
  table_cols_uncleaned = table.find('thead').find('tr')
  table_cols = [col for col in table_cols_uncleaned if type(col) != bs4.element.NavigableString]


  #No longer career per game
  #table_vals = table.find('tfoot').find('tr')

  #Instead we are getting the final season
  table_vals = table.findAll("tr")[-2]

  table_dict = {f"{col.getText().replace(' ', '_')}_{table_id}":val.getText() for col, val in zip(table_cols, table_vals)}

  #TODO: Change this (can make this line better anyway)
  keys_to_remove = ['Age', 'Lg', 'Pos', 'Tm', '\xa0']

  for key in keys_to_remove:
    table_dict.pop(f'{key}_{table_id}', None)
  
  # keys_to_replace = ['Season', 'Conf', 'G', 'GS', 'School']

  # for key in keys_to_replace:
  #   table_dict[key] = table_dict[f'{key}_{table_id}']
  #   table_dict.pop(f'{key}_{table_id}', None)


  #Will only be for advanced- Win shares for now
  #Grab all stats from one column and get their max/peak
  # for peak_stat in peak_stats:
  #   peak_stat_tds = table.find('tbody').findAll(attrs={'data-stat':peak_stat})
  #   peak_stat_values = [float(td.getText()) for td in peak_stat_tds if td.getText() != '']
  #   table_dict[f'peak_{peak_stat}_{table_id}'] = max(peak_stat_values) if len(peak_stat_values) > 0 else 0

  return table_dict

# %%
def get_accolade_dictionary(soup, accolade_cols):
  """

  Extracts player accolades from their website and returns in the form of a
  dictionary


  Args:
    soup: Soup extracted from an individual player's website on Basketball
     Reference

  
  Returns:
    [dict]: Returns a dictionary with the name of the accolade as the key
      and the number of times the player achieved it

  """

  # Accolade col (need to watch out for 2x, 3x, etc)

  # Conference wise accolades (For ACC, Big Ten, Pac 12, Big 12)
  # {year} All-{Conference}
  # {Conference} All-Freshman
  # {year} {Conference} POY
  # {Conference} All-Defense
  # {year} {Conference} ROY

  power_conferences = ['ACC', 'Pac-12', 'Big Ten', 'Big 12']

  # Naismith Award, {year} AP POY, NCAA All-Region, NCAA Champion, Wooden Award, Rupp Trophy, NCAA Tourney MOP


  #Hard coded as will only use this function for accolades, as other data comes
  #in table form

  bling = soup.find(id='bling')

  accolade_dict = {}

  if bling == None:
    return accolade_dict

  #Couldn't do simple BAA -> NBA replace as often put BAA/NBA
  replacer_dict = {
    'ACC': 'P4_Conference',
    'Big Ten': 'P4_Conference',
    'Pac-12': 'P4_Conference',
    'Big 12': 'P4_Conference', 
    ' *': '',
    ' ' : '_',
    '-' : '_',
    '.': ''
  }

  #For now
  accolades_list = [li.getText() for li in bling.findAll('li')]

  for i, accolade in enumerate(accolades_list):
    #For cases:
    #1978-79 NBA Champ
    #1978 Scoring Leader
    accolade = re.sub(r'(\d{4}-\d{2})|(\d{4})', '1x', accolade)
    #accolade = re.sub(r'\d{4}-\d{2}', '1x', accolade)
    accolade = multiple_replace(replacer_dict, accolade)

    parts = accolade.split('x_')
    accolade_name = parts[1] if len(parts) > 1 else parts[0]

    if accolade_name not in accolade_cols:
      continue 

    accolade_dict[accolade_name] = parts[0] if len(parts) > 1 else 1
    
  return accolade_dict

# %%
def scrape_player_data(combine_data, identifier_cols, physical_cols, per_game_cols, accolade_cols, advanced_cols):

  final_cols = identifier_cols + accolade_cols + per_game_cols + physical_cols + advanced_cols
  all_data = []

  #For every player in draft:
  for i, row in combine_data.iterrows():
    current_name = row['Player']
    draft_class = row['Draft Year']
    
    # Open href:
    href_name = current_name.lower().replace(' ', '-')
    player_url = f"https://www.sports-reference.com/cbb/players/{href_name}-1.html" 
      
    # player_url = f"https://www.sports-reference.com/cbb/players/{href}"
    player_html = urlopen(player_url)
    player_soup = BeautifulSoup(player_html, features="lxml")

    accolade_dict = get_accolade_dictionary(player_soup, accolade_cols)
    per_game_dict = get_table_dictionary(player_soup, 'per_game')
    physical_dict = get_physical_dictionary(player_soup)

    try:
      advanced_dict = get_table_dictionary(player_soup, 'advanced')
    except:
      print("Exception: ")
      print(current_name)
      continue

    # Will put 0s for accolades that did not exist- should look at how long
    # each has existed
    accolade_list = dict_to_list(accolade_dict, accolade_cols, 0)

    # NAs for stats not recorded
    per_game_list = dict_to_list(per_game_dict, per_game_cols, -999)
    physical_list = dict_to_list(physical_dict, physical_cols, -999)
    advanced_list = dict_to_list(advanced_dict, advanced_cols, -999)

    #Eligibility- If ended after 2018 then can join 2022
    #Active will be train/val and test split
    # eligible = getEligible(player_soup.find(id='per_game'))

    identifier_list = [current_name, draft_class]

    current_player_data = identifier_list + accolade_list + per_game_list + physical_list + advanced_list

    all_data.append(current_player_data)
      
  output_df = pd.DataFrame(data=all_data, columns = final_cols)

  return output_df

# %%
combine_data = pd.read_csv('https://raw.githubusercontent.com/frankwillard/NBA-Rookie-Success-ML-Model/main/NBA%20Combine%20Measurements%20-%202010-2022.csv')

# %%
# combine_data = combine_data.sort_values(by=['Player'])

# %%
identifier_cols = ['Player', 'Draft Year']

#College, Rankings, etc

accolade_cols = ['All_P4_Conference', 'P4_Conference_All_Freshman', 'P4_Conference_POY', 'P4_Conference_All_Defense', 'P4_Conference_ROY', 'Naismith_Award', 'AP_POY', 'NCAA_All_Region', 'NCAA_Champion', 'Wooden_Award', 'Rupp_Trophy', 'NCAA_Tourney_MOP']
# Should also collect year and something like "Eligible" in terms of having a test set of the last few draft classes
# identifier_cols = ['Player', 'Eligible']

physical_cols = ["Position", "Height", "Weight"]

# Currently include SOS as measure of strength of schedule
per_game_cols = ['Season_per_game','School_per_game','Conf_per_game','G_per_game','GS_per_game','MP_per_game','FG_per_game','FGA_per_game','FG%_per_game','2P_per_game','2PA_per_game','2P%_per_game','3P_per_game','3PA_per_game','3P%_per_game','FT_per_game','FTA_per_game','FT%_per_game','ORB_per_game','DRB_per_game','TRB_per_game','AST_per_game','STL_per_game','BLK_per_game','TOV_per_game','PF_per_game','PTS_per_game','SOS_per_game']

# Could look into other percentages like assist, eFG, PProd
advanced_cols = ['PER_advanced', 'TS%_advanced', 'PProd_advanced', 'OWS_advanced', 'DWS_advanced', 'WS_advanced', 'WS/40_advanced', 'OBPM_advanced', 'DBPM_advanced', 'BPM_advanced', 'VORP_advanced']

# %%
scrape_player_data(combine_data, identifier_cols, physical_cols, per_game_cols, accolade_cols, advanced_cols)
# Out:
# https://www.sports-reference.com/cbb/players/solomon-alabi-1.html
# https://www.sports-reference.com/cbb/players/cole-aldrich-1.html
# https://www.sports-reference.com/cbb/players/al-farouq-aminu-1.html
# https://www.sports-reference.com/cbb/players/james-anderson-1.html
# https://www.sports-reference.com/cbb/players/luke-babbitt-1.html
# https://www.sports-reference.com/cbb/players/eric-bledsoe-1.html
# https://www.sports-reference.com/cbb/players/trevor-booker-1.html
# https://www.sports-reference.com/cbb/players/craig-brackins-1.html
# https://www.sports-reference.com/cbb/players/avery-bradley-1.html
# https://www.sports-reference.com/cbb/players/derrick-caracter-1.html
# https://www.sports-reference.com/cbb/players/sherron-collins-1.html
# https://www.sports-reference.com/cbb/players/demarcus-cousins-1.html
# https://www.sports-reference.com/cbb/players/jordan-crawford-1.html
# https://www.sports-reference.com/cbb/players/ed-davis-1.html
# https://www.sports-reference.com/cbb/players/devin-ebanks-1.html
# https://www.sports-reference.com/cbb/players/derrick-favors-1.html
# https://www.sports-reference.com/cbb/players/keith-gallon-1.html
# https://www.sports-reference.com/cbb/players/charles-garcia-1.html
# https://www.sports-reference.com/cbb/players/paul-george-1.html
# https://www.sports-reference.com/cbb/players/luke-harangody-1.html
# https://www.sports-reference.com/cbb/players/manny-harris-1.html
# https://www.sports-reference.com/cbb/players/lazar-hayward-1.html
# https://www.sports-reference.com/cbb/players/gordon-hayward-1.html
# https://www.sports-reference.com/cbb/players/xavier-henry-1.html
# https://www.sports-reference.com/cbb/players/darington-hobson-1.html
# https://www.sports-reference.com/cbb/players/damion-james-1.html
# https://www.sports-reference.com/cbb/players/wesley-johnson-1.html
# https://www.sports-reference.com/cbb/players/armon-johnson-1.html
# https://www.sports-reference.com/cbb/players/dominique-jones-1.html
# https://www.sports-reference.com/cbb/players/jerome-jordan-1.html
# https://www.sports-reference.com/cbb/players/sylven-landesberg-1.html
# https://www.sports-reference.com/cbb/players/gani-lawal-1.html
# https://www.sports-reference.com/cbb/players/greg-monroe-1.html
# https://www.sports-reference.com/cbb/players/daniel-orton-1.html
# https://www.sports-reference.com/cbb/players/artsiom-parakhouski-1.html
# https://www.sports-reference.com/cbb/players/patrick-patterson-1.html
# https://www.sports-reference.com/cbb/players/dexter-pittman-1.html
# https://www.sports-reference.com/cbb/players/andy-rautins-1.html
# https://www.sports-reference.com/cbb/players/ryan-richards-1.html
# https://www.sports-reference.com/cbb/players/stanley-robinson-1.html
# https://www.sports-reference.com/cbb/players/larry-sanders-1.html
# https://www.sports-reference.com/cbb/players/jon-scheyer-1.html
# https://www.sports-reference.com/cbb/players/lance-stephenson-1.html
# https://www.sports-reference.com/cbb/players/mikhail-torrance-1.html
# https://www.sports-reference.com/cbb/players/evan-turner-1.html
# https://www.sports-reference.com/cbb/players/ekpe-udoh-1.html
# https://www.sports-reference.com/cbb/players/jarvis-varnado-1.html
# https://www.sports-reference.com/cbb/players/greivis-vasquez-1.html
# https://www.sports-reference.com/cbb/players/john-wall-1.html
# https://www.sports-reference.com/cbb/players/willie-warren-1.html
# https://www.sports-reference.com/cbb/players/terrico-white-1.html
# https://www.sports-reference.com/cbb/players/hassan-whiteside-1.html
# https://www.sports-reference.com/cbb/players/keith-benson-1.html
# https://www.sports-reference.com/cbb/players/marshon-brooks-1.html
# https://www.sports-reference.com/cbb/players/alec-burks-1.html
# https://www.sports-reference.com/cbb/players/jimmy-butler-1.html
# https://www.sports-reference.com/cbb/players/norris-cole-1.html
# https://www.sports-reference.com/cbb/players/jon-diebler-1.html
# https://www.sports-reference.com/cbb/players/michael-dunigan-1.html
# https://www.sports-reference.com/cbb/players/lacedarius-dunn-1.html
# https://www.sports-reference.com/cbb/players/kenneth-faried-1.html
# https://www.sports-reference.com/cbb/players/james-fredette-1.html
# https://www.sports-reference.com/cbb/players/andrew-goudelock-1.html
# https://www.sports-reference.com/cbb/players/jordan-hamilton-1.html
# https://www.sports-reference.com/cbb/players/justin-harper-1.html
# https://www.sports-reference.com/cbb/players/tobias-harris-1.html
# https://www.sports-reference.com/cbb/players/tyler-honeycutt-1.html
# https://www.sports-reference.com/cbb/players/scotty-hopson-1.html
# https://www.sports-reference.com/cbb/players/kyrie-irving-1.html
# https://www.sports-reference.com/cbb/players/rick-jackson-1.html
# https://www.sports-reference.com/cbb/players/charles-jenkins-1.html
# https://www.sports-reference.com/cbb/players/jajuan-johnson-1.html
# https://www.sports-reference.com/cbb/players/cory-joseph-1.html
# https://www.sports-reference.com/cbb/players/enes-kanter-1.html
# https://www.sports-reference.com/cbb/players/brandon-knight-1.html
# https://www.sports-reference.com/cbb/players/malcolm-lee-1.html
# https://www.sports-reference.com/cbb/players/kawhi-leonard-1.html
# https://www.sports-reference.com/cbb/players/travis-leslie-1.html
# https://www.sports-reference.com/cbb/players/jon-leuer-1.html
# https://www.sports-reference.com/cbb/players/deandre-liggins-1.html
# https://www.sports-reference.com/cbb/players/david-lighty-1.html
# https://www.sports-reference.com/cbb/players/shelvin-mack-1.html
# https://www.sports-reference.com/cbb/players/demetri-mccamey-1.html
# https://www.sports-reference.com/cbb/players/e'twaun-moore-1.html
# https://www.sports-reference.com/cbb/players/marcus-morris-1.html
# https://www.sports-reference.com/cbb/players/markieff-morris-1.html
# https://www.sports-reference.com/cbb/players/darius-morris-1.html
# https://www.sports-reference.com/cbb/players/chandler-parsons-1.html
# https://www.sports-reference.com/cbb/players/jereme-richmond-1.html
# https://www.sports-reference.com/cbb/players/josh-selby-1.html
# https://www.sports-reference.com/cbb/players/iman-shumpert-1.html
# https://www.sports-reference.com/cbb/players/kyle-singler-1.html
# https://www.sports-reference.com/cbb/players/chris-singleton-1.html
# https://www.sports-reference.com/cbb/players/jamie-skeen-1.html
# https://www.sports-reference.com/cbb/players/nolan-smith-1.html
# https://www.sports-reference.com/cbb/players/gregory-smith-1.html
# https://www.sports-reference.com/cbb/players/malcolm-thomas-1.html
# https://www.sports-reference.com/cbb/players/isaiah-thomas-1.html
# https://www.sports-reference.com/cbb/players/trey-thompkins-1.html
# https://www.sports-reference.com/cbb/players/tristan-thompson-1.html
# https://www.sports-reference.com/cbb/players/klay-thompson-1.html
# https://www.sports-reference.com/cbb/players/jeremy-tyler-1.html
# https://www.sports-reference.com/cbb/players/nikola-vucevic-1.html
# https://www.sports-reference.com/cbb/players/kemba-walker-1.html
# https://www.sports-reference.com/cbb/players/jordan-williams-1.html
# https://www.sports-reference.com/cbb/players/derrick-williams-1.html
# https://www.sports-reference.com/cbb/players/quincy-acy-1.html
# https://www.sports-reference.com/cbb/players/harrison-barnes-1.html
# https://www.sports-reference.com/cbb/players/will-barton-1.html
# https://www.sports-reference.com/cbb/players/bradley-beal-1.html
# https://www.sports-reference.com/cbb/players/j'covan-brown-1.html
# https://www.sports-reference.com/cbb/players/william-buford-1.html
# https://www.sports-reference.com/cbb/players/jae-crowder-1.html
# https://www.sports-reference.com/cbb/players/jared-cunningham-1.html
# https://www.sports-reference.com/cbb/players/anthony-davis-1.html
# https://www.sports-reference.com/cbb/players/marcus-denmon-1.html
# https://www.sports-reference.com/cbb/players/andre-drummond-1.html
# https://www.sports-reference.com/cbb/players/kim-english-1.html
# https://www.sports-reference.com/cbb/players/festus-ezeli-1.html
# https://www.sports-reference.com/cbb/players/drew-gordon-1.html
# https://www.sports-reference.com/cbb/players/jamychal-green-1.html
# https://www.sports-reference.com/cbb/players/draymond-green-1.html
# https://www.sports-reference.com/cbb/players/maurice-harkless-1.html
# https://www.sports-reference.com/cbb/players/john-henson-1.html
# https://www.sports-reference.com/cbb/players/tu-holloway-1.html
# https://www.sports-reference.com/cbb/players/robbie-hummel-1.html
# https://www.sports-reference.com/cbb/players/bernard-james-1.html
# https://www.sports-reference.com/cbb/players/john-jenkins-1.html
# https://www.sports-reference.com/cbb/players/orlando-johnson-1.html
# https://www.sports-reference.com/cbb/players/darius-johnson-odom-1.html
# https://www.sports-reference.com/cbb/players/terrence-jones-1.html
# https://www.sports-reference.com/cbb/players/kevin-jones-1.html
# https://www.sports-reference.com/cbb/players/perry-jones-1.html
# https://www.sports-reference.com/cbb/players/kris-joseph-1.html
# https://www.sports-reference.com/cbb/players/michael-kidd-gilchrist-1.html
# https://www.sports-reference.com/cbb/players/doron-lamb-1.html
# https://www.sports-reference.com/cbb/players/jeremy-lamb-1.html
# https://www.sports-reference.com/cbb/players/meyers-leonard-1.html
# https://www.sports-reference.com/cbb/players/damian-lillard-1.html
# https://www.sports-reference.com/cbb/players/scott-machado-1.html
# https://www.sports-reference.com/cbb/players/kendall-marshall-1.html
# https://www.sports-reference.com/cbb/players/fab-melo-1.html
# https://www.sports-reference.com/cbb/players/khris-middleton-1.html
# https://www.sports-reference.com/cbb/players/darius-miller-1.html
# https://www.sports-reference.com/cbb/players/quincy-miller-1.html
# https://www.sports-reference.com/cbb/players/tony-mitchell-1.html
# https://www.sports-reference.com/cbb/players/arnett-moultrie-1.html
# https://www.sports-reference.com/cbb/players/kevin-murphy-1.html
# https://www.sports-reference.com/cbb/players/andrew-nicholson-1.html
# https://www.sports-reference.com/cbb/players/kyle-o'quinn-1.html
# https://www.sports-reference.com/cbb/players/miles-plumlee-1.html
# https://www.sports-reference.com/cbb/players/austin-rivers-1.html
# https://www.sports-reference.com/cbb/players/thomas-robinson-1.html
# https://www.sports-reference.com/cbb/players/terrence-ross-1.html
# https://www.sports-reference.com/cbb/players/tomas-satoransky-1.html
# https://www.sports-reference.com/cbb/players/mike-scott-1.html
# https://www.sports-reference.com/cbb/players/henry-sims-1.html
# https://www.sports-reference.com/cbb/players/jared-sullinger-1.html
# https://www.sports-reference.com/cbb/players/tyshawn-taylor-1.html
# https://www.sports-reference.com/cbb/players/jordan-taylor-1.html
# https://www.sports-reference.com/cbb/players/jeff-taylor-1.html
# https://www.sports-reference.com/cbb/players/marquis-teague-1.html
# https://www.sports-reference.com/cbb/players/hollis-thompson-1.html
# https://www.sports-reference.com/cbb/players/dion-waiters-1.html
# https://www.sports-reference.com/cbb/players/royce-white-1.html
# https://www.sports-reference.com/cbb/players/tony-wroten-1.html
# https://www.sports-reference.com/cbb/players/tyler-zeller-1.html
# https://www.sports-reference.com/cbb/players/steven-adams-1.html
# https://www.sports-reference.com/cbb/players/vander-blue-1.html
# https://www.sports-reference.com/cbb/players/lorenzo-brown-1.html
# https://www.sports-reference.com/cbb/players/reggie-bullock-1.html
# https://www.sports-reference.com/cbb/players/trey-burke-1.html
# https://www.sports-reference.com/cbb/players/kentavious-caldwell-pope-1.html
# https://www.sports-reference.com/cbb/players/isaiah-canaan-1.html
# https://www.sports-reference.com/cbb/players/jackie-carmichael-1.html
# https://www.sports-reference.com/cbb/players/michael-carter-williams-1.html
# https://www.sports-reference.com/cbb/players/will-clyburn-1.html
# https://www.sports-reference.com/cbb/players/robert-covington-1.html
# https://www.sports-reference.com/cbb/players/allen-crabbe-1.html
# https://www.sports-reference.com/cbb/players/seth-curry-1.html
# https://www.sports-reference.com/cbb/players/brandon-davies-1.html
# https://www.sports-reference.com/cbb/players/dewayne-dedmon-1.html
# https://www.sports-reference.com/cbb/players/gorgui-dieng-1.html
# https://www.sports-reference.com/cbb/players/james-ennis-1.html
# https://www.sports-reference.com/cbb/players/carrick-felix-1.html
# https://www.sports-reference.com/cbb/players/jamaal-franklin-1.html
# https://www.sports-reference.com/cbb/players/rudy-gobert-1.html
# https://www.sports-reference.com/cbb/players/archie-goodwin-1.html
# https://www.sports-reference.com/cbb/players/erick-green-1.html
# https://www.sports-reference.com/cbb/players/tim-hardaway-jr.-1.html
# https://www.sports-reference.com/cbb/players/solomon-hill-1.html
# https://www.sports-reference.com/cbb/players/richard-howell-1.html
# https://www.sports-reference.com/cbb/players/colton-iverson-1.html
# https://www.sports-reference.com/cbb/players/pierre-jackson-1.html
# https://www.sports-reference.com/cbb/players/grant-jerrett-1.html
# https://www.sports-reference.com/cbb/players/myck-kabongo-1.html
# https://www.sports-reference.com/cbb/players/kenny-kadji-1.html
# https://www.sports-reference.com/cbb/players/ryan-kelly-1.html
# https://www.sports-reference.com/cbb/players/shane-larkin-1.html
# https://www.sports-reference.com/cbb/players/ricky-ledo-1.html
# https://www.sports-reference.com/cbb/players/alex-len-1.html
# https://www.sports-reference.com/cbb/players/cj-leslie-1.html
# https://www.sports-reference.com/cbb/players/trevor-mbakwe-1.html
# https://www.sports-reference.com/cbb/players/ray-mccallum-1.html
# https://www.sports-reference.com/cbb/players/cj-mccollum-1.html
# https://www.sports-reference.com/cbb/players/ben-mclemore-1.html
# https://www.sports-reference.com/cbb/players/tony-mitchell-1.html
# https://www.sports-reference.com/cbb/players/shabazz-muhammad-1.html
# https://www.sports-reference.com/cbb/players/erik-murphy-1.html
# https://www.sports-reference.com/cbb/players/mike-muscala-1.html
# https://www.sports-reference.com/cbb/players/nerlens-noel-1.html
# https://www.sports-reference.com/cbb/players/victor-oladipo-1.html
# https://www.sports-reference.com/cbb/players/kelly-olynyk-1.html
# https://www.sports-reference.com/cbb/players/brandon-paul-1.html
# https://www.sports-reference.com/cbb/players/norvel-pelle-1.html
# https://www.sports-reference.com/cbb/players/mason-plumlee-1.html
# https://www.sports-reference.com/cbb/players/otto-porter-1.html
# https://www.sports-reference.com/cbb/players/phil-pressey-1.html
# https://www.sports-reference.com/cbb/players/glen-rice-1.html
# https://www.sports-reference.com/cbb/players/andre-roberson-1.html
# https://www.sports-reference.com/cbb/players/dennis-schroder-1.html
# https://www.sports-reference.com/cbb/players/peyton-siva-1.html
# https://www.sports-reference.com/cbb/players/tony-snell-1.html
# https://www.sports-reference.com/cbb/players/james-southerland-1.html
# https://www.sports-reference.com/cbb/players/adonis-thomas-1.html
# https://www.sports-reference.com/cbb/players/deshaun-thomas-1.html
# https://www.sports-reference.com/cbb/players/jeff-withey-1.html
# https://www.sports-reference.com/cbb/players/nate-wolters-1.html
# https://www.sports-reference.com/cbb/players/bj-young-1.html
# https://www.sports-reference.com/cbb/players/cody-zeller-1.html
# https://www.sports-reference.com/cbb/players/jordan-adams-1.html
# https://www.sports-reference.com/cbb/players/kyle-anderson-1.html
# https://www.sports-reference.com/cbb/players/thanasis-antetokounmpo-1.html
# https://www.sports-reference.com/cbb/players/jordan-bachynski-1.html
# https://www.sports-reference.com/cbb/players/cameron-bairstow-1.html
# https://www.sports-reference.com/cbb/players/khem-birch-1.html
# https://www.sports-reference.com/cbb/players/alec-brown-1.html
# https://www.sports-reference.com/cbb/players/markel-brown-1.html
# https://www.sports-reference.com/cbb/players/jabari-brown-1.html
# https://www.sports-reference.com/cbb/players/deonte-burton-1.html
# https://www.sports-reference.com/cbb/players/semaj-christon-1.html
# https://www.sports-reference.com/cbb/players/jordan-clarkson-1.html
# https://www.sports-reference.com/cbb/players/aaron-craft-1.html
# https://www.sports-reference.com/cbb/players/deandre-daniels-1.html
# https://www.sports-reference.com/cbb/players/spencer-dinwiddie-1.html
# https://www.sports-reference.com/cbb/players/cleanthony-early-1.html
# https://www.sports-reference.com/cbb/players/melvin-ejim-1.html
# https://www.sports-reference.com/cbb/players/tyler-ennis-1.html
# https://www.sports-reference.com/cbb/players/dante-exum-1.html
# https://www.sports-reference.com/cbb/players/c.j.-fair-1.html
# https://www.sports-reference.com/cbb/players/aaron-gordon-1.html
# https://www.sports-reference.com/cbb/players/jerami-grant-1.html
# https://www.sports-reference.com/cbb/players/p.j.-hairston-1.html
# https://www.sports-reference.com/cbb/players/gary-harris-1.html
# https://www.sports-reference.com/cbb/players/joe-harris-1.html
# https://www.sports-reference.com/cbb/players/rodney-hood-1.html
# https://www.sports-reference.com/cbb/players/cory-jefferson-1.html
# https://www.sports-reference.com/cbb/players/nick-johnson-1.html
# https://www.sports-reference.com/cbb/players/sean-kilpatrick-1.html
# https://www.sports-reference.com/cbb/players/alex-kirk-1.html
# https://www.sports-reference.com/cbb/players/zach-lavine-1.html
# https://www.sports-reference.com/cbb/players/devyn-marble-1.html
# https://www.sports-reference.com/cbb/players/james-mcadoo-1.html
# https://www.sports-reference.com/cbb/players/k.j.-mcdaniels-1.html
# https://www.sports-reference.com/cbb/players/doug-mcdermott-1.html
# https://www.sports-reference.com/cbb/players/jordan-mcrae-1.html
# https://www.sports-reference.com/cbb/players/shabazz-napier-1.html
# https://www.sports-reference.com/cbb/players/johnny-o?bryant-iii-1.html
# https://www.sports-reference.com/cbb/players/lamar-patterson-1.html
# https://www.sports-reference.com/cbb/players/adreian-payne-1.html
# https://www.sports-reference.com/cbb/players/elfrid-payton-1.html
# https://www.sports-reference.com/cbb/players/dwight-powell-1.html
# https://www.sports-reference.com/cbb/players/julius-randle-1.html
# https://www.sports-reference.com/cbb/players/glenn-robinson-iii-1.html
# https://www.sports-reference.com/cbb/players/laquinton-ross-1.html
# https://www.sports-reference.com/cbb/players/marcus-smart-1.html
# https://www.sports-reference.com/cbb/players/russ-smith-1.html
# https://www.sports-reference.com/cbb/players/nik-stauskas-1.html
# https://www.sports-reference.com/cbb/players/jarnell-stokes-1.html
# https://www.sports-reference.com/cbb/players/xavier-thames-1.html
# https://www.sports-reference.com/cbb/players/noah-vonleh-1.html
# https://www.sports-reference.com/cbb/players/t.j.-warren-1.html
# https://www.sports-reference.com/cbb/players/c.j.-wilcox-1.html
# https://www.sports-reference.com/cbb/players/kendall-williams-1.html
# https://www.sports-reference.com/cbb/players/patric-young-1.html
# https://www.sports-reference.com/cbb/players/james-young-1.html
# https://www.sports-reference.com/cbb/players/cliff-alexander-1.html
# https://www.sports-reference.com/cbb/players/justin-anderson-1.html
# https://www.sports-reference.com/cbb/players/brandon-ashley-1.html
# https://www.sports-reference.com/cbb/players/ryan-boatright-1.html
# https://www.sports-reference.com/cbb/players/devin-booker-1.html
# https://www.sports-reference.com/cbb/players/anthony-brown-1.html
# https://www.sports-reference.com/cbb/players/willie-cauley-stein-1.html
# https://www.sports-reference.com/cbb/players/rakeem-christmas-1.html
# https://www.sports-reference.com/cbb/players/pat-connaughton-1.html
# https://www.sports-reference.com/cbb/players/quinn-cook-1.html
# https://www.sports-reference.com/cbb/players/branden-dawson-1.html
# https://www.sports-reference.com/cbb/players/sam-dekker-1.html
# https://www.sports-reference.com/cbb/players/michael-frazier-ii-1.html
# https://www.sports-reference.com/cbb/players/treveon-graham-1.html
# https://www.sports-reference.com/cbb/players/jerian-grant-1.html
# https://www.sports-reference.com/cbb/players/olivier-hanlan-1.html
# https://www.sports-reference.com/cbb/players/montrezl-harrell-1.html
# https://www.sports-reference.com/cbb/players/andrew-harrison-1.html
# https://www.sports-reference.com/cbb/players/aaron-harrison-1.html
# https://www.sports-reference.com/cbb/players/tyler-harvey-1.html
# https://www.sports-reference.com/cbb/players/corey-hawkins-1.html
# https://www.sports-reference.com/cbb/players/rondae-hollis-jefferson-1.html
# https://www.sports-reference.com/cbb/players/richaun-holmes-1.html
# https://www.sports-reference.com/cbb/players/jonathan-holmes-1.html
# https://www.sports-reference.com/cbb/players/r.j.-hunter-1.html
# https://www.sports-reference.com/cbb/players/vince-hunter-1.html
# https://www.sports-reference.com/cbb/players/dakari-johnson-1.html
# https://www.sports-reference.com/cbb/players/stanley-johnson-1.html
# https://www.sports-reference.com/cbb/players/tyus-jones-1.html
# https://www.sports-reference.com/cbb/players/frank-kaminsky-1.html
# https://www.sports-reference.com/cbb/players/kevon-looney-1.html
# https://www.sports-reference.com/cbb/players/trey-lyles-1.html
# https://www.sports-reference.com/cbb/players/jarell-martin-1.html
# https://www.sports-reference.com/cbb/players/tj-mcconnell-1.html
# https://www.sports-reference.com/cbb/players/chris-mccullough-1.html
# https://www.sports-reference.com/cbb/players/jordan-mickey-1.html
# https://www.sports-reference.com/cbb/players/larry-nance-1.html
# https://www.sports-reference.com/cbb/players/kelly-oubre-1.html
# https://www.sports-reference.com/cbb/players/cameron-payne-1.html
# https://www.sports-reference.com/cbb/players/terran-petteway-1.html
# https://www.sports-reference.com/cbb/players/bobby-portis-1.html
# https://www.sports-reference.com/cbb/players/norman-powell-1.html
# https://www.sports-reference.com/cbb/players/michael-qualls-1.html
# https://www.sports-reference.com/cbb/players/chasson-randle-1.html
# https://www.sports-reference.com/cbb/players/terry-rozier-1.html
# https://www.sports-reference.com/cbb/players/d?angelo-russell-1.html
# https://www.sports-reference.com/cbb/players/keifer-sykes-1.html
# https://www.sports-reference.com/cbb/players/marcus-thornton-1.html
# https://www.sports-reference.com/cbb/players/j.p.-tokoto-1.html
# https://www.sports-reference.com/cbb/players/myles-turner-1.html
# https://www.sports-reference.com/cbb/players/robert-upshaw-1.html
# https://www.sports-reference.com/cbb/players/rashad-vaughn-1.html
# https://www.sports-reference.com/cbb/players/chris-walker-1.html
# https://www.sports-reference.com/cbb/players/dez-wells-1.html
# https://www.sports-reference.com/cbb/players/alan-williams-1.html
# https://www.sports-reference.com/cbb/players/justise-winslow-1.html
# https://www.sports-reference.com/cbb/players/christian-wood-1.html
# https://www.sports-reference.com/cbb/players/delon-wright-1.html
# https://www.sports-reference.com/cbb/players/ron-baker-1.html
# https://www.sports-reference.com/cbb/players/wade-baldwin-iv-1.html
# https://www.sports-reference.com/cbb/players/cat-barber-1.html
# https://www.sports-reference.com/cbb/players/malik-beasley-1.html
# https://www.sports-reference.com/cbb/players/deandre-bembry-1.html
# https://www.sports-reference.com/cbb/players/ben-bentil-1.html
# https://www.sports-reference.com/cbb/players/jaron-blossomgame-1.html
# https://www.sports-reference.com/cbb/players/joel-bolomboy-1.html
# https://www.sports-reference.com/cbb/players/malcolm-brogdon-1.html
# https://www.sports-reference.com/cbb/players/jaylen-brown-1.html
# https://www.sports-reference.com/cbb/players/marquese-chriss-1.html
# https://www.sports-reference.com/cbb/players/elgin-cook-1.html
# https://www.sports-reference.com/cbb/players/isaiah-cousins-1.html
# https://www.sports-reference.com/cbb/players/deyonta-davis-1.html
# https://www.sports-reference.com/cbb/players/cheick-diallo-1.html
# https://www.sports-reference.com/cbb/players/kris-dunn-1.html
# https://www.sports-reference.com/cbb/players/henry-ellenson-1.html
# https://www.sports-reference.com/cbb/players/perry-ellis-1.html
# https://www.sports-reference.com/cbb/players/kay-felder-1.html
# https://www.sports-reference.com/cbb/players/dorian-finney-smith-1.html
# https://www.sports-reference.com/cbb/players/michael-gbinije-1.html
# https://www.sports-reference.com/cbb/players/daniel-hamilton-1.html
# https://www.sports-reference.com/cbb/players/josh-hart-1.html
# https://www.sports-reference.com/cbb/players/nigel-hayes-1.html
# https://www.sports-reference.com/cbb/players/buddy-hield-1.html
# https://www.sports-reference.com/cbb/players/justin-jackson-1.html
# https://www.sports-reference.com/cbb/players/demetrius-jackson-1.html
# https://www.sports-reference.com/cbb/players/brice-johnson-1.html
# https://www.sports-reference.com/cbb/players/damian-jones-1.html
# https://www.sports-reference.com/cbb/players/skal-labissiere-1.html
# https://www.sports-reference.com/cbb/players/jake-layman-1.html
# https://www.sports-reference.com/cbb/players/caris-levert-1.html
# https://www.sports-reference.com/cbb/players/marcus-lee-1.html
# https://www.sports-reference.com/cbb/players/thon-maker-1.html
# https://www.sports-reference.com/cbb/players/patrick-mccaw-1.html
# https://www.sports-reference.com/cbb/players/malik-newman-1.html
# https://www.sports-reference.com/cbb/players/georges-niang-1.html
# https://www.sports-reference.com/cbb/players/chinanu-onuaku-1.html
# https://www.sports-reference.com/cbb/players/marcus-paige-1.html
# https://www.sports-reference.com/cbb/players/gary-payton-ii-1.html
# https://www.sports-reference.com/cbb/players/jakob-poeltl-1.html
# https://www.sports-reference.com/cbb/players/taurean-prince-1.html
# https://www.sports-reference.com/cbb/players/zhou-qi-1.html
# https://www.sports-reference.com/cbb/players/malachi-richardson-1.html
# https://www.sports-reference.com/cbb/players/wayne-selden-1.html
# https://www.sports-reference.com/cbb/players/pascal-siakam-1.html
# https://www.sports-reference.com/cbb/players/diamond-stone-1.html
# https://www.sports-reference.com/cbb/players/caleb-swanigan-1.html
# https://www.sports-reference.com/cbb/players/melo-trimble-1.html
# https://www.sports-reference.com/cbb/players/tyler-ulis-1.html
# https://www.sports-reference.com/cbb/players/jarrod-uthoff-1.html
# https://www.sports-reference.com/cbb/players/denzel-valentine-1.html
# https://www.sports-reference.com/cbb/players/isaiah-whitehead-1.html
# https://www.sports-reference.com/cbb/players/troy-williams-1.html
# https://www.sports-reference.com/cbb/players/kyle-wiltjer-1.html
# https://www.sports-reference.com/cbb/players/stephen-zimmerman-1.html
# https://www.sports-reference.com/cbb/players/edrice-adebayo-1.html
# https://www.sports-reference.com/cbb/players/rawle-alkins-1.html
# https://www.sports-reference.com/cbb/players/jarrett-allen-1.html
# https://www.sports-reference.com/cbb/players/kadeem-allen-1.html
# https://www.sports-reference.com/cbb/players/ike-anigbogu-1.html
# https://www.sports-reference.com/cbb/players/og-anunoby-1.html
# https://www.sports-reference.com/cbb/players/jamel-artis-1.html
# https://www.sports-reference.com/cbb/players/dwayne-bacon-1.html
# https://www.sports-reference.com/cbb/players/v.j.-beachem-1.html
# https://www.sports-reference.com/cbb/players/jordan-bell-1.html
# https://www.sports-reference.com/cbb/players/jaron-blossomgame-1.html
# https://www.sports-reference.com/cbb/players/chris-boucher-1.html
# https://www.sports-reference.com/cbb/players/tony-bradley-1.html
# https://www.sports-reference.com/cbb/players/isaiah-briscoe-1.html
# https://www.sports-reference.com/cbb/players/dillon-brooks-1.html
# https://www.sports-reference.com/cbb/players/thomas-bryant-1.html
# https://www.sports-reference.com/cbb/players/zach-collins-1.html
# https://www.sports-reference.com/cbb/players/john-collins-1.html
# https://www.sports-reference.com/cbb/players/hamidou-diallo-1.html
# https://www.sports-reference.com/cbb/players/tyler-dorsey-1.html
# https://www.sports-reference.com/cbb/players/damyean-dotson-1.html
# https://www.sports-reference.com/cbb/players/pj-dozier-1.html
# https://www.sports-reference.com/cbb/players/jawun-evans-1.html
# https://www.sports-reference.com/cbb/players/terrance-ferguson-1.html
# https://www.sports-reference.com/cbb/players/de?aaron-fox-1.html
# https://www.sports-reference.com/cbb/players/markelle-fultz-1.html
# https://www.sports-reference.com/cbb/players/harry-giles-1.html
# https://www.sports-reference.com/cbb/players/josh-hart-1.html
# https://www.sports-reference.com/cbb/players/nigel-hayes-1.html
# https://www.sports-reference.com/cbb/players/isaiah-hicks-1.html
# https://www.sports-reference.com/cbb/players/wesley-iwundu-1.html
# https://www.sports-reference.com/cbb/players/frank-jackson-1.html
# https://www.sports-reference.com/cbb/players/justin-jackson-(umd)-1.html
# https://www.sports-reference.com/cbb/players/justin-jackson-(unc)-1.html
# https://www.sports-reference.com/cbb/players/peter-jok-1.html
# https://www.sports-reference.com/cbb/players/luke-kennard-1.html
# https://www.sports-reference.com/cbb/players/kyle-kuzma-1.html
# https://www.sports-reference.com/cbb/players/tj-leaf-1.html
# https://www.sports-reference.com/cbb/players/tyler-lydon-1.html
# https://www.sports-reference.com/cbb/players/frank-mason-iii-1.html
# https://www.sports-reference.com/cbb/players/kennedy-meeks-1.html
# https://www.sports-reference.com/cbb/players/donovan-mitchell-1.html
# https://www.sports-reference.com/cbb/players/monte-morris-1.html
# https://www.sports-reference.com/cbb/players/johnathan-motley-1.html
# https://www.sports-reference.com/cbb/players/svi-mykhailiuk-1.html
# https://www.sports-reference.com/cbb/players/semi-ojeleye-1.html
# https://www.sports-reference.com/cbb/players/cameron-oliver-1.html
# https://www.sports-reference.com/cbb/players/justin-patton-1.html
# https://www.sports-reference.com/cbb/players/alec-peters-1.html
# https://www.sports-reference.com/cbb/players/ivan-rabb-1.html
# https://www.sports-reference.com/cbb/players/davon-reed-1.html
# https://www.sports-reference.com/cbb/players/devin-robinson-1.html
# https://www.sports-reference.com/cbb/players/kobi-simmons-1.html
# https://www.sports-reference.com/cbb/players/edmond-sumner-1.html
# https://www.sports-reference.com/cbb/players/caleb-swanigan-1.html
# https://www.sports-reference.com/cbb/players/sindarius-thornwell-1.html
# https://www.sports-reference.com/cbb/players/melo-trimble-1.html
# https://www.sports-reference.com/cbb/players/moritz-wagner-1.html
# https://www.sports-reference.com/cbb/players/derrick-walton-jr.-1.html
# https://www.sports-reference.com/cbb/players/thomas-welsh-1.html
# https://www.sports-reference.com/cbb/players/derrick-white-1.html
# https://www.sports-reference.com/cbb/players/nigel-williams-goss-1.html
# https://www.sports-reference.com/cbb/players/d.j.-wilson-1.html
# https://www.sports-reference.com/cbb/players/omer-yurtseven-1.html
# https://www.sports-reference.com/cbb/players/rawle-alkins-1.html
# https://www.sports-reference.com/cbb/players/grayson-allen-1.html
# https://www.sports-reference.com/cbb/players/kostas-antetokounmpo-1.html
# https://www.sports-reference.com/cbb/players/udoka-azubuike-1.html
# https://www.sports-reference.com/cbb/players/mohamed-bamba-1.html
# https://www.sports-reference.com/cbb/players/jaylen-barford-1.html
# https://www.sports-reference.com/cbb/players/keita-bates-diop-1.html
# https://www.sports-reference.com/cbb/players/tyus-battle-1.html
# https://www.sports-reference.com/cbb/players/brian-bowen-1.html
# https://www.sports-reference.com/cbb/players/miles-bridges-1.html
# https://www.sports-reference.com/cbb/players/bruce-brown-1.html
# https://www.sports-reference.com/cbb/players/troy-brown-1.html
# https://www.sports-reference.com/cbb/players/jalen-brunson-1.html
# https://www.sports-reference.com/cbb/players/tony-carr-1.html
# https://www.sports-reference.com/cbb/players/jevon-carter-1.html
# https://www.sports-reference.com/cbb/players/wendell-carter-1.html
# https://www.sports-reference.com/cbb/players/donte-divincenzo-1.html
# https://www.sports-reference.com/cbb/players/hamidou-diallo-1.html
# https://www.sports-reference.com/cbb/players/trevon-duval-1.html
# https://www.sports-reference.com/cbb/players/carsen-edwards-1.html
# https://www.sports-reference.com/cbb/players/keenan-evans-1.html
# https://www.sports-reference.com/cbb/players/jacob-evans-1.html
# https://www.sports-reference.com/cbb/players/bruno-fernando-1.html
# https://www.sports-reference.com/cbb/players/melvin-frazier-1.html
# https://www.sports-reference.com/cbb/players/shai-gilgeous-alexander-1.html
# https://www.sports-reference.com/cbb/players/devonte-graham-1.html
# https://www.sports-reference.com/cbb/players/isaac-haas-1.html
# https://www.sports-reference.com/cbb/players/devon-hall-1.html
# https://www.sports-reference.com/cbb/players/jaylen-hands-1.html
# https://www.sports-reference.com/cbb/players/kevin-hervey-1.html
# https://www.sports-reference.com/cbb/players/aaron-holiday-1.html
# https://www.sports-reference.com/cbb/players/kevin-huerter-1.html
# https://www.sports-reference.com/cbb/players/jaren-jackson-1.html
# https://www.sports-reference.com/cbb/players/justin-jackson-1.html
# https://www.sports-reference.com/cbb/players/alize-johnson-1.html
# https://www.sports-reference.com/cbb/players/george-king-1.html
# https://www.sports-reference.com/cbb/players/kevin-knox-1.html
# https://www.sports-reference.com/cbb/players/sagaba-konate-1.html
# https://www.sports-reference.com/cbb/players/caleb-martin-1.html
# https://www.sports-reference.com/cbb/players/cody-martin-1.html
# https://www.sports-reference.com/cbb/players/yante-maten-1.html
# https://www.sports-reference.com/cbb/players/brandon-mccoy-1.html
# https://www.sports-reference.com/cbb/players/deanthony-melton-1.html
# https://www.sports-reference.com/cbb/players/chimezie-metu-1.html
# https://www.sports-reference.com/cbb/players/shake-milton-1.html
# https://www.sports-reference.com/cbb/players/sviatoslav-mykhailiuk-1.html
# https://www.sports-reference.com/cbb/players/malik-newman-1.html
# https://www.sports-reference.com/cbb/players/josh-okogie-1.html
# https://www.sports-reference.com/cbb/players/theo-pinson-1.html
# https://www.sports-reference.com/cbb/players/jontay-porter-1.html
# https://www.sports-reference.com/cbb/players/michael-porter-1.html
# https://www.sports-reference.com/cbb/players/billy-preston-1.html
# https://www.sports-reference.com/cbb/players/jerome-robinson-1.html
# https://www.sports-reference.com/cbb/players/collin-sexton-1.html
# https://www.sports-reference.com/cbb/players/landry-shamet-1.html
# https://www.sports-reference.com/cbb/players/anfernee-simons-1.html
# https://www.sports-reference.com/cbb/players/zhaire-smith-1.html
# https://www.sports-reference.com/cbb/players/ray-spalding-1.html
# https://www.sports-reference.com/cbb/players/omari-spellman-1.html
# https://www.sports-reference.com/cbb/players/khyri-thomas-1.html
# https://www.sports-reference.com/cbb/players/gary-trent-1.html
# https://www.sports-reference.com/cbb/players/allonzo-trier-1.html
# https://www.sports-reference.com/cbb/players/moritz-wagner-1.html
# https://www.sports-reference.com/cbb/players/lonnie-walker-1.html
# https://www.sports-reference.com/cbb/players/pj-washington-1.html
# https://www.sports-reference.com/cbb/players/austin-wiley-1.html
# https://www.sports-reference.com/cbb/players/kris-wilkes-1.html
# https://www.sports-reference.com/cbb/players/kenrich-williams-1.html
# https://www.sports-reference.com/cbb/players/trae-young-1.html
# https://www.sports-reference.com/cbb/players/nickeil-alexander-walker-1.html
# https://www.sports-reference.com/cbb/players/rj-barrett-1.html
# https://www.sports-reference.com/cbb/players/charles-bassey-1.html
# https://www.sports-reference.com/cbb/players/darius-bazley-1.html
# https://www.sports-reference.com/cbb/players/bol-bol-1.html
# https://www.sports-reference.com/cbb/players/jordan-bone-1.html
# https://www.sports-reference.com/cbb/players/brian-bowen-ii-1.html
# https://www.sports-reference.com/cbb/players/ky-bowman-1.html
# https://www.sports-reference.com/cbb/players/ignas-brazdeikis-1.html
# https://www.sports-reference.com/cbb/players/o'shae-brissett-1.html
# https://www.sports-reference.com/cbb/players/moses-brown-1.html
# https://www.sports-reference.com/cbb/players/brandon-clarke-1.html
# https://www.sports-reference.com/cbb/players/nicolas-claxton-1.html
# https://www.sports-reference.com/cbb/players/tyler-cook-1.html
# https://www.sports-reference.com/cbb/players/jarrett-culver-1.html
# https://www.sports-reference.com/cbb/players/terence-davis-1.html
# https://www.sports-reference.com/cbb/players/luguentz-dort-1.html
# https://www.sports-reference.com/cbb/players/devon-dotson-1.html
# https://www.sports-reference.com/cbb/players/carsen-edwards-1.html
# https://www.sports-reference.com/cbb/players/tacko-fall-1.html
# https://www.sports-reference.com/cbb/players/bruno-fernando-1.html
# https://www.sports-reference.com/cbb/players/daniel-gafford-1.html
# https://www.sports-reference.com/cbb/players/darius-garland-1.html
# https://www.sports-reference.com/cbb/players/quentin-grimes-1.html
# https://www.sports-reference.com/cbb/players/kyle-guy-1.html
# https://www.sports-reference.com/cbb/players/jaylen-hands-1.html
# https://www.sports-reference.com/cbb/players/jared-harper-1.html
# https://www.sports-reference.com/cbb/players/jaxson-hayes-1.html
# https://www.sports-reference.com/cbb/players/dewan-hernandez-1.html
# https://www.sports-reference.com/cbb/players/tyler-herro-1.html
# https://www.sports-reference.com/cbb/players/jalen-hoard-1.html
# https://www.sports-reference.com/cbb/players/talen-horton-tucker-1.html
# https://www.sports-reference.com/cbb/players/de'andre-hunter-1.html
# https://www.sports-reference.com/cbb/players/daquan-jeffries-1.html
# https://www.sports-reference.com/cbb/players/ty-jerome-1.html
# https://www.sports-reference.com/cbb/players/keldon-johnson-1.html
# https://www.sports-reference.com/cbb/players/cameron-johnson-1.html
# https://www.sports-reference.com/cbb/players/mfiondu-kabengele-1.html
# https://www.sports-reference.com/cbb/players/louis-king-1.html
# https://www.sports-reference.com/cbb/players/romeo-langford-1.html
# https://www.sports-reference.com/cbb/players/dedric-lawson-1.html
# https://www.sports-reference.com/cbb/players/jalen-lecque-1.html
# https://www.sports-reference.com/cbb/players/nassir-little-1.html
# https://www.sports-reference.com/cbb/players/terance-mann-1.html
# https://www.sports-reference.com/cbb/players/cody-martin-1.html
# https://www.sports-reference.com/cbb/players/charles-matthews-1.html
# https://www.sports-reference.com/cbb/players/jalen-mcdaniels-1.html
# https://www.sports-reference.com/cbb/players/ja-morant-1.html
# https://www.sports-reference.com/cbb/players/zach-norvell-jr.-1.html
# https://www.sports-reference.com/cbb/players/jaylen-nowell-1.html
# https://www.sports-reference.com/cbb/players/jordan-nwora-1.html
# https://www.sports-reference.com/cbb/players/chuma-okeke-1.html
# https://www.sports-reference.com/cbb/players/kz-okpala-1.html
# https://www.sports-reference.com/cbb/players/miye-oni-1.html
# https://www.sports-reference.com/cbb/players/eric-paschall-1.html
# https://www.sports-reference.com/cbb/players/reggie-perry-1.html
# https://www.sports-reference.com/cbb/players/shamorie-ponds-1.html
# https://www.sports-reference.com/cbb/players/jordan-poole-1.html
# https://www.sports-reference.com/cbb/players/jontay-porter-1.html
# https://www.sports-reference.com/cbb/players/kevin-porter-jr.-1.html
# https://www.sports-reference.com/cbb/players/neemias-queta-1.html
# https://www.sports-reference.com/cbb/players/cameron-reddish-1.html
# https://www.sports-reference.com/cbb/players/naz-reid-1.html
# https://www.sports-reference.com/cbb/players/isaiah-roby-1.html
# https://www.sports-reference.com/cbb/players/luka-samanic-1.html
# https://www.sports-reference.com/cbb/players/admiral-schofield-1.html
# https://www.sports-reference.com/cbb/players/marial-shayok-1.html
# https://www.sports-reference.com/cbb/players/simisola-shittu-1.html
# https://www.sports-reference.com/cbb/players/killian-tillie-1.html
# https://www.sports-reference.com/cbb/players/p.j.-washington-1.html
# https://www.sports-reference.com/cbb/players/tremont-waters-1.html
# https://www.sports-reference.com/cbb/players/quinndary-weatherspoon-1.html
# https://www.sports-reference.com/cbb/players/coby-white-1.html
# https://www.sports-reference.com/cbb/players/kris-wilkes-1.html
# https://www.sports-reference.com/cbb/players/grant-williams-1.html
# https://www.sports-reference.com/cbb/players/zion-williamson-1.html
# https://www.sports-reference.com/cbb/players/dylan-windler-1.html
# https://www.sports-reference.com/cbb/players/precious-achiuwa-1.html
# https://www.sports-reference.com/cbb/players/ty-shon-alexander-1.html
# https://www.sports-reference.com/cbb/players/udoka-azubuike-1.html
# https://www.sports-reference.com/cbb/players/tyler-bey-1.html
# https://www.sports-reference.com/cbb/players/yoeli-childs-1.html
# https://www.sports-reference.com/cbb/players/mamadi-diakite-1.html
# https://www.sports-reference.com/cbb/players/devon-dotson-1.html
# https://www.sports-reference.com/cbb/players/paul-eboua-1.html
# https://www.sports-reference.com/cbb/players/cj-elleby-1.html
# https://www.sports-reference.com/cbb/players/trent-forrest-1.html
# https://www.sports-reference.com/cbb/players/josh-green-1.html
# https://www.sports-reference.com/cbb/players/ashton-hagans-1.html
# https://www.sports-reference.com/cbb/players/joshua-hall-1.html
# https://www.sports-reference.com/cbb/players/jalen-harris-1.html
# https://www.sports-reference.com/cbb/players/markus-howard-1.html
# https://www.sports-reference.com/cbb/players/elijah-hughes-1.html
# https://www.sports-reference.com/cbb/players/isaiah-joe-1.html
# https://www.sports-reference.com/cbb/players/mason-jones-1.html
# https://www.sports-reference.com/cbb/players/nathan-knight-1.html
# https://www.sports-reference.com/cbb/players/theo-maledon-1.html
# https://www.sports-reference.com/cbb/players/karim-mane-1.html
# https://www.sports-reference.com/cbb/players/naji-marshall-1.html
# https://www.sports-reference.com/cbb/players/kenyon-martin-jr.-1.html
# https://www.sports-reference.com/cbb/players/skylar-mays-1.html
# https://www.sports-reference.com/cbb/players/zeke-nnaji-1.html
# https://www.sports-reference.com/cbb/players/jordan-nwora-1.html
# https://www.sports-reference.com/cbb/players/reggie-perry-1.html
# https://www.sports-reference.com/cbb/players/myles-powell-1.html
# https://www.sports-reference.com/cbb/players/immanuel-quickley-1.html
# https://www.sports-reference.com/cbb/players/jahmi'us-ramsey-1.html
# https://www.sports-reference.com/cbb/players/paul-reed-jr.-1.html
# https://www.sports-reference.com/cbb/players/nick-richards-1.html
# https://www.sports-reference.com/cbb/players/grant-riller-1.html
# https://www.sports-reference.com/cbb/players/jayden-scrubb-1.html
# https://www.sports-reference.com/cbb/players/jalen-smith-1.html
# https://www.sports-reference.com/cbb/players/cassius-stanley-1.html
# https://www.sports-reference.com/cbb/players/lamar-stevens-1.html
# https://www.sports-reference.com/cbb/players/isaiah-stewart-1.html
# https://www.sports-reference.com/cbb/players/tyrell-terry-1.html
# https://www.sports-reference.com/cbb/players/killian-tillie-1.html
# https://www.sports-reference.com/cbb/players/xavier-tillman-sr.-1.html
# https://www.sports-reference.com/cbb/players/kaleb-wesson-1.html
# https://www.sports-reference.com/cbb/players/kahlil-whitney-1.html
# https://www.sports-reference.com/cbb/players/cassius-winston-1.html
# https://www.sports-reference.com/cbb/players/robert-woodard-ii-1.html
# https://www.sports-reference.com/cbb/players/max-abmas-1.html
# https://www.sports-reference.com/cbb/players/ochai-agbaji-1.html
# https://www.sports-reference.com/cbb/players/marcus-bagley-1.html
# https://www.sports-reference.com/cbb/players/scottie-barnes-1.html
# https://www.sports-reference.com/cbb/players/charles-bassey-1.html
# https://www.sports-reference.com/cbb/players/brandon-boston-jr.-1.html
# https://www.sports-reference.com/cbb/players/james-bouknight-1.html
# https://www.sports-reference.com/cbb/players/greg-brown-iii-1.html
# https://www.sports-reference.com/cbb/players/jared-butler-1.html
# https://www.sports-reference.com/cbb/players/julian-champagnie-1.html
# https://www.sports-reference.com/cbb/players/justin-champagnie-1.html
# https://www.sports-reference.com/cbb/players/josh-christopher-1.html
# https://www.sports-reference.com/cbb/players/sharife-cooper-1.html
# https://www.sports-reference.com/cbb/players/cade-cunningham-1.html
# https://www.sports-reference.com/cbb/players/ayo-dosunmu-1.html
# https://www.sports-reference.com/cbb/players/david-duke-jr.-1.html
# https://www.sports-reference.com/cbb/players/kessler-edwards-1.html
# https://www.sports-reference.com/cbb/players/luka-garza-1.html
# https://www.sports-reference.com/cbb/players/raiquan-gray-1.html
# https://www.sports-reference.com/cbb/players/jalen-green-1.html
# https://www.sports-reference.com/cbb/players/quentin-grimes-1.html
# https://www.sports-reference.com/cbb/players/sam-hauser-1.html
# https://www.sports-reference.com/cbb/players/aaron-henry-1.html
# https://www.sports-reference.com/cbb/players/ariel-hukporti-1.html
# https://www.sports-reference.com/cbb/players/matt-hurt-1.html
# https://www.sports-reference.com/cbb/players/nah'shon-hyland-1.html
# https://www.sports-reference.com/cbb/players/isaiah-jackson-1.html
# https://www.sports-reference.com/cbb/players/david-johnson-1.html
# https://www.sports-reference.com/cbb/players/jalen-johnson-1.html
# https://www.sports-reference.com/cbb/players/keon-johnson-1.html
# https://www.sports-reference.com/cbb/players/carlik-jones-1.html
# https://www.sports-reference.com/cbb/players/kai-jones-1.html
# https://www.sports-reference.com/cbb/players/herbert-jones-1.html
# https://www.sports-reference.com/cbb/players/johnny-juzang-1.html
# https://www.sports-reference.com/cbb/players/corey-kispert-1.html
# https://www.sports-reference.com/cbb/players/jonathan-kuminga-1.html
# https://www.sports-reference.com/cbb/players/aj-lawson-1.html
# https://www.sports-reference.com/cbb/players/scottie-lewis-1.html
# https://www.sports-reference.com/cbb/players/isaiah-livers-1.html
# https://www.sports-reference.com/cbb/players/makur-maker-1.html
# https://www.sports-reference.com/cbb/players/sandro-mamukelashvili-1.html
# https://www.sports-reference.com/cbb/players/tre-mann-1.html
# https://www.sports-reference.com/cbb/players/matthew-mayer-1.html
# https://www.sports-reference.com/cbb/players/miles-mcbride-1.html
# https://www.sports-reference.com/cbb/players/davion-mitchell-1.html
# https://www.sports-reference.com/cbb/players/evan-mobley-1.html
# https://www.sports-reference.com/cbb/players/isaiah-mobley-1.html
# https://www.sports-reference.com/cbb/players/moses-moody-1.html
# https://www.sports-reference.com/cbb/players/trey-murphy-iii-1.html
# https://www.sports-reference.com/cbb/players/daishen-nix-1.html
# https://www.sports-reference.com/cbb/players/john-petty-jr.-1.html
# https://www.sports-reference.com/cbb/players/yves-pons-1.html
# https://www.sports-reference.com/cbb/players/jason-preston-1.html
# https://www.sports-reference.com/cbb/players/joshua-primo-1.html
# https://www.sports-reference.com/cbb/players/roko-prkacin-1.html
# https://www.sports-reference.com/cbb/players/neemias-queta-1.html
# https://www.sports-reference.com/cbb/players/austin-reaves-1.html
# https://www.sports-reference.com/cbb/players/jeremiah-robinson-earl-1.html
# https://www.sports-reference.com/cbb/players/terrence-shannon-jr.-1.html
# https://www.sports-reference.com/cbb/players/day'ron-sharpe-1.html
# https://www.sports-reference.com/cbb/players/jericho-sims-1.html
# https://www.sports-reference.com/cbb/players/jaden-springer-1.html
# https://www.sports-reference.com/cbb/players/dj-steward-1.html
# https://www.sports-reference.com/cbb/players/cam-thomas-1.html
# https://www.sports-reference.com/cbb/players/jt-thor-1.html
# https://www.sports-reference.com/cbb/players/isaiah-todd-1.html
# https://www.sports-reference.com/cbb/players/duane-washington-jr.-1.html
# https://www.sports-reference.com/cbb/players/trendon-watford-1.html
# https://www.sports-reference.com/cbb/players/joe-wieskamp-1.html
# https://www.sports-reference.com/cbb/players/aaron-wiggins-1.html
# https://www.sports-reference.com/cbb/players/ziaire-williams-1.html
# https://www.sports-reference.com/cbb/players/moses-wright-1.html
# https://www.sports-reference.com/cbb/players/mckinley-wright-iv-1.html
# https://www.sports-reference.com/cbb/players/marcus-zegarowski-1.html
# https://www.sports-reference.com/cbb/players/ochai-agbaji-1.html
# https://www.sports-reference.com/cbb/players/patrick-baldwin-jr.-1.html
# https://www.sports-reference.com/cbb/players/paolo-banchero-1.html
# https://www.sports-reference.com/cbb/players/dominick-barlow-1.html
# https://www.sports-reference.com/cbb/players/marjon-beauchamp-1.html
# https://www.sports-reference.com/cbb/players/hugo-besson-1.html
# https://www.sports-reference.com/cbb/players/malaki-branham-1.html
# https://www.sports-reference.com/cbb/players/christian-braun-1.html
# https://www.sports-reference.com/cbb/players/kendall-brown-1.html
# https://www.sports-reference.com/cbb/players/john-butler-jr.-1.html
# https://www.sports-reference.com/cbb/players/julian-champagnie-1.html
# https://www.sports-reference.com/cbb/players/kennedy-chandler-1.html
# https://www.sports-reference.com/cbb/players/max-christie-1.html
# https://www.sports-reference.com/cbb/players/kofi-cockburn-1.html
# https://www.sports-reference.com/cbb/players/dyson-daniels-1.html
# https://www.sports-reference.com/cbb/players/johnny-davis-1.html
# https://www.sports-reference.com/cbb/players/jd-davison-1.html
# https://www.sports-reference.com/cbb/players/darius-days-1.html
# https://www.sports-reference.com/cbb/players/moussa-diabate-1.html
# https://www.sports-reference.com/cbb/players/ousmane-dieng-1.html
# https://www.sports-reference.com/cbb/players/khalifa-diop-1.html
# https://www.sports-reference.com/cbb/players/jalen-duren-1.html
# https://www.sports-reference.com/cbb/players/tari-eason-1.html
# https://www.sports-reference.com/cbb/players/keon-ellis-1.html
# https://www.sports-reference.com/cbb/players/michael-foster-jr.-1.html
# https://www.sports-reference.com/cbb/players/collin-gillespie-1.html
# https://www.sports-reference.com/cbb/players/aj-griffin-1.html
# https://www.sports-reference.com/cbb/players/jaden-hardy-1.html
# https://www.sports-reference.com/cbb/players/ron-harper-jr.-1.html
# https://www.sports-reference.com/cbb/players/chet-holmgren-1.html
# https://www.sports-reference.com/cbb/players/harrison-ingram-1.html
# https://www.sports-reference.com/cbb/players/jaden-ivey-1.html
# https://www.sports-reference.com/cbb/players/trayce-jackson-davis-1.html
# https://www.sports-reference.com/cbb/players/nikola-jovic-1.html
# https://www.sports-reference.com/cbb/players/johnny-juzang-1.html
# https://www.sports-reference.com/cbb/players/ismael-kamagate-1.html
# https://www.sports-reference.com/cbb/players/trevor-keels-1.html
# https://www.sports-reference.com/cbb/players/walker-kessler-1.html
# https://www.sports-reference.com/cbb/players/christian-koloko-1.html
# https://www.sports-reference.com/cbb/players/jake-laravia-1.html
# https://www.sports-reference.com/cbb/players/justin-lewis-1.html
# https://www.sports-reference.com/cbb/players/e.j.-liddell-1.html
# https://www.sports-reference.com/cbb/players/kenneth-lofton-jr.-1.html
# https://www.sports-reference.com/cbb/players/tyrese-martin-1.html
# https://www.sports-reference.com/cbb/players/bennedict-mathurin-1.html
# https://www.sports-reference.com/cbb/players/matthew-mayer-1.html
# https://www.sports-reference.com/cbb/players/bryce-mcgowens-1.html
# https://www.sports-reference.com/cbb/players/leonard-miller-1.html
# https://www.sports-reference.com/cbb/players/josh-minnott-1.html
# https://www.sports-reference.com/cbb/players/aminu-mohammed-1.html
# https://www.sports-reference.com/cbb/players/iverson-molinar-1.html
# https://www.sports-reference.com/cbb/players/jean-montero-1.html
# https://www.sports-reference.com/cbb/players/wendell-moore-1.html
# https://www.sports-reference.com/cbb/players/keegan-murray-1.html
# https://www.sports-reference.com/cbb/players/andrew-nembhard-1.html
# https://www.sports-reference.com/cbb/players/scotty-pippen-jr.-1.html
# https://www.sports-reference.com/cbb/players/gabriele-procida-1.html
# https://www.sports-reference.com/cbb/players/jared-rhoden-1.html
# https://www.sports-reference.com/cbb/players/orlando-robinson-1.html
# https://www.sports-reference.com/cbb/players/david-roddy-1.html
# https://www.sports-reference.com/cbb/players/ryan-rollins-1.html
# https://www.sports-reference.com/cbb/players/marcus-sasser-1.html
# https://www.sports-reference.com/cbb/players/dereon-seabron-1.html
# https://www.sports-reference.com/cbb/players/shaedon-sharpe-1.html
# https://www.sports-reference.com/cbb/players/terquavion-smith-1.html
# https://www.sports-reference.com/cbb/players/jabari-smith-1.html
# https://www.sports-reference.com/cbb/players/jeremy-sochan-1.html
# https://www.sports-reference.com/cbb/players/matteo-spagnolo-1.html
# https://www.sports-reference.com/cbb/players/julian-strawther-1.html
# https://www.sports-reference.com/cbb/players/dalen-terry-1.html
# https://www.sports-reference.com/cbb/players/drew-timme-1.html
# https://www.sports-reference.com/cbb/players/jabari-walker-1.html
# https://www.sports-reference.com/cbb/players/tyty-washington-jr.-1.html
# https://www.sports-reference.com/cbb/players/peyton-watson-1.html
# https://www.sports-reference.com/cbb/players/blake-wesley-1.html
# https://www.sports-reference.com/cbb/players/alondes-williams-1.html
# https://www.sports-reference.com/cbb/players/jalen-williams-1.html
# https://www.sports-reference.com/cbb/players/jaylin-williams-1.html
# https://www.sports-reference.com/cbb/players/trevion-williams-1.html
# https://www.sports-reference.com/cbb/players/bryson-williams-1.html
# https://www.sports-reference.com/cbb/players/mark-williams-1.html
# https://www.sports-reference.com/cbb/players/jalen-wilson-1.html
# https://www.sports-reference.com/cbb/players/fanbo-zeng-1.html
